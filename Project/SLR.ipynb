# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df = pd.read_excel(r"C:\Users\Lenovo\Documents\Book1.xlsx")
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area(sqt.ft)')
plt.ylabel('Price')
plt.scatter(df['Area'],df['Price'])
plt.plot(df.Area,reg.predict(df[['Area']]),color = 'black')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Area']],df['Price'])
# Out:
# LinearRegression()

# %%
reg.predict(np.array([[3300]]))
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
import pickle

# %%
with open('reg_pickle','wb') as f:
    pickle.dump(reg,f)

# %%
from sklearn.externals import joblib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from sklearn.externals import joblib
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\externals\__init__.py)
